# %%
import pandas as pd
import numpy as np

# %%
# %matplotlib inline

# %%
df0 = pd.read_json('/data/data.json', lines=True)
df0.dtypes

# %%
df_payload = pd.DataFrame(df0['payload_fields'].values.tolist())
df_payload.dtypes

# %%
df = pd.concat([df0.drop(columns=['payload_fields']), df_payload], axis=1)
df['time'] = df0['metadata'].apply(lambda x: np.datetime64(x['time']))
df

# %%
df.plot('time', 'bmp280_te')
